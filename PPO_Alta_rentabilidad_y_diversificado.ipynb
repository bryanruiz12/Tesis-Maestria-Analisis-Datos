# %% [markdown]
# **ESCENARIO DONDE PRIORIZO LA DIVERSIFICACIÓN Y LA RENTABILIDAD**

# %%
# 1. INSTALACIONES

# !pip install stable-baselines3[extra] gymnasium yfinance pandas numpy matplotlib


# 2. IMPORTACIONES

import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from collections import deque
import warnings

warnings.filterwarnings('ignore', category=FutureWarning, module='yfinance')

print("\n--- Librerías importadas ---")

# 3. EL ENTORNO (con Recompensa de Sharpe)

class PortfolioRebalancingEnv(gym.Env):
    def __init__(self, data, initial_balance=10000, transaction_cost_pct=0.001,
                 reward_window_size=20):
        super(PortfolioRebalancingEnv, self).__init__()
        self.data = data
        self.n_steps, self.n_assets = data.shape
        self.asset_names = data.columns.tolist()
        self.initial_balance = initial_balance
        self.transaction_cost_pct = transaction_cost_pct
        self.reward_window_size = reward_window_size
        self.return_history = deque(maxlen=self.reward_window_size)
        self.action_space = spaces.Box(low=0, high=1, shape=(self.n_assets + 1,), dtype=np.float32)
        self.observation_space = spaces.Box(low=0, high=np.inf, shape=(2 * self.n_assets + 1,), dtype=np.float32)
        self.initial_asset_prices = self.data.iloc[0].values
        self.current_step = 0
        self.balance = 0
        self.holdings = np.zeros(self.n_assets)
        self.asset_prices = np.zeros(self.n_assets)
        self.portfolio_value_history = []
        self.reset()
    def _get_observation(self):
        safe_initial_prices = np.where(self.initial_asset_prices == 0, 1, self.initial_asset_prices)
        normalized_prices = self.asset_prices / safe_initial_prices
        normalized_holdings = (self.holdings * self.asset_prices) / self.initial_balance
        normalized_balance = self.balance / self.initial_balance
        obs = np.concatenate([normalized_prices, normalized_holdings, [normalized_balance]]).astype(np.float32)
        return obs
    def _get_info(self):
        portfolio_value = self.balance + np.sum(self.holdings * self.asset_prices)
        return {"portfolio_value": portfolio_value, "balance": self.balance,
                "holdings": self.holdings, "asset_prices": self.asset_prices}
    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.balance = self.initial_balance
        self.holdings = np.zeros(self.n_assets)
        self.asset_prices = self.data.iloc[self.current_step].values
        self.portfolio_value_history = [self.initial_balance]
        self.return_history.clear()
        observation = self._get_observation()
        info = self._get_info()
        return observation, info
    def step(self, action):
        previous_portfolio_value = self.balance + np.sum(self.holdings * self.asset_prices)
        action_sum = np.sum(action)
        if action_sum <= 1e-6:
            weights = np.zeros(self.n_assets + 1); weights[-1] = 1.0
        else:
            weights = action / action_sum
        target_weights = weights[:-1]; cash_weight = weights[-1]
        total_value_to_rebalance = previous_portfolio_value
        target_asset_values = total_value_to_rebalance * target_weights
        trade_costs = 0
        new_holdings = np.zeros(self.n_assets)
        for i in range(self.n_assets):
            current_value = self.holdings[i] * self.asset_prices[i]
            delta_value = target_asset_values[i] - current_value
            if self.asset_prices[i] > 1e-6:
                delta_shares = delta_value / self.asset_prices[i]
                cost = abs(delta_value) * self.transaction_cost_pct
                trade_costs += cost
                new_holdings[i] = self.holdings[i] + delta_shares
            else:
                new_holdings[i] = self.holdings[i]
        self.balance = (total_value_to_rebalance * cash_weight) - trade_costs
        self.holdings = new_holdings
        self.current_step += 1
        terminated = self.current_step >= (self.n_steps - 1)
        truncated = False
        self.asset_prices = self.data.iloc[self.current_step].values
        current_portfolio_value = self.balance + np.sum(self.holdings * self.asset_prices)
        if previous_portfolio_value <= 1e-6: daily_return = 0.0
        else: daily_return = (current_portfolio_value - previous_portfolio_value) / previous_portfolio_value
        self.return_history.append(daily_return)
        if len(self.return_history) < 2: reward = 0.0
        else:
            rolling_std = np.std(self.return_history)
            if rolling_std < 1e-6: reward = daily_return
            else: reward = daily_return / rolling_std
        self.portfolio_value_history.append(current_portfolio_value)
        observation = self._get_observation()
        info = self._get_info()
        return observation, reward, terminated, truncated, info

print("\n--- Clase de Entorno 'PortfolioRebalancingEnv' definida ---")


# 4. FUNCIÓN PARA DIVIDIR LOS DATOS

def split_data_chronological(data, test_size_pct=0.2):
    n_total = len(data); n_test = int(n_total * test_size_pct); n_train = n_total - n_test
    data_train = data.iloc[:n_train]; data_test = data.iloc[n_train:]
    print(f"Datos totales: {n_total} días")
    print(f"Datos de entrenamiento (Train): {len(data_train)} días (del {data_train.index.min().date()} al {data_train.index.max().date()})")
    print(f"Datos de prueba (Test): {len(data_test)} días (del {data_test.index.min().date()} al {data_test.index.max().date()})")
    return data_train, data_test
print("\n--- Función 'split_data_chronological' definida ---")


# 5. CARGA Y DIVISIÓN DE DATOS

tickers = ['SPY', 'DAX', 'GLD']
start_date = '2015-01-01'
end_date = '2025-06-30'
INITIAL_BALANCE = 10000

data = yf.download(tickers, start=start_date, end=end_date)['Close']
data.ffill(inplace=True); data.bfill(inplace=True)
print(f"\n--- Datos descargados para {tickers} ---")
data_train, data_test = split_data_chronological(data, test_size_pct=0.2)


# 6. ENTRENAMIENTO DEL MODELO PPO

print("\n--- Iniciando entrenamiento PPO (Recompensa de Sharpe) ---")
env_train = PortfolioRebalancingEnv(data_train, initial_balance=INITIAL_BALANCE, reward_window_size=20)
env_train = DummyVecEnv([lambda: env_train])

model = PPO("MlpPolicy", env_train, verbose=1,
            tensorboard_log="./ppo_portfolio_tesis_log_sharpe/")

# Usamos 200000 steps
TIMESTEPS_TO_TRAIN = 200000
model.learn(total_timesteps=TIMESTEPS_TO_TRAIN)

print(f"\n--- Entrenamiento completado tras {TIMESTEPS_TO_TRAIN} timesteps ---")



# 7. EVALUACIÓN (OUT-OF-SAMPLE) - Probando el modelo en los datos de TEST

print("\n--- Evaluando el modelo (Sharpe) en el set de 'TEST' (Out-of-Sample) ---")

env_eval_test = PortfolioRebalancingEnv(data_test, initial_balance=INITIAL_BALANCE, reward_window_size=20)
obs, info = env_eval_test.reset()
done = False
truncated = False

# Listas para guardar el historial
ppo_test_history = [INITIAL_BALANCE] # Historial del valor del portafolio
weights_history = []                 # Historial de los pesos de la cartera

# Reiniciar el bucle para empezar desde el historial reseteado
obs, info = env_eval_test.reset()
while not done:
    action, _states = model.predict(obs, deterministic=True)

    # Guardar la acción (pesos) en cada paso! ***
    weights_history.append(action)

    obs, reward, done, truncated, info = env_eval_test.step(action)

    # Guardamos el valor del portafolio desde el 'info' dict
    if not done:
        ppo_test_history.append(info['portfolio_value'])

print("--- Evaluación 'Out-of-Sample' (Test) completada ---")


# 8. CÁLCULO DE TABLAS y BENCHMARK ("VALOR REAL")

# Procesar el historial de pesos
# 1. Normalizar todos los pesos guardados para que sumen 1
normalized_weights_history = [w / np.sum(w) for w in weights_history]
# 2. Crear un DataFrame con ellos
asset_columns = tickers + ['Cash']
weights_df = pd.DataFrame(normalized_weights_history, columns=asset_columns)


# Calcular métricas de rendimiento (Basadas en el historial de valor)
# Estas métricas YA representan el desempeño promedio/total del período
returns_test = pd.Series(ppo_test_history).pct_change().dropna()
volatilidad_test = returns_test.std() * np.sqrt(252)
sharpe_ratio_test = 0.0
if volatilidad_test > 1e-6:
    retorno_esperado_test = returns_test.mean() * 252
    sharpe_ratio_test = retorno_esperado_test / volatilidad_test
else:
    retorno_esperado_test = 0.0


# Calcular Pesos PROMEDIO
# Calcular el promedio de las asignaciones de pesos durante todo el período
avg_weights = weights_df.mean()
w_spy_avg = avg_weights['SPY']
w_dax_avg = avg_weights['DAX']
w_gld_avg = avg_weights['GLD']
w_cash_avg = avg_weights['Cash']


# Imprimir la tabla de resultados PROMEDIO
# Esta tabla ahora combina las métricas de rendimiento
# con TODOS los pesos PROMEDIO.
summary_data_avg = {
    'Portafolio': ['PPO (RL) - Promedio (Test)'],
    'Retorno Esperado': [retorno_esperado_test],
    'Volatilidad': [volatilidad_test],
    'Sharpe Ratio': [sharpe_ratio_test],
    'W_SPY (Promedio)': [w_spy_avg],
    'W_DAX (Promedio)': [w_dax_avg],
    'W_GLD (Promedio)': [w_gld_avg],
    'W_Cash (Promedio)': [w_cash_avg],
}
df_resultado_promedio_rl = pd.DataFrame(summary_data_avg)

print("\n\n" + "="*70)
print("  RESULTADO PROMEDIO DE EVALUACIÓN (TEST SET) - ESTRATEGIA PPO")
print("="*70)
print(df_resultado_promedio_rl.to_markdown(index=False))


# --- Calcular Benchmark "Buy & Hold SPY" ("Valor Real")
print("Calculando Benchmark 'Buy & Hold SPY' ('Valor Real')")
spy_test_history = (data_test['SPY'] / data_test['SPY'].iloc[0]) * INITIAL_BALANCE



# 9. GRÁFICO COMPARATIVO (REAL vs. PREDICHO en Set de TEST)

print("Generando gráfico 1: 'Real' vs. 'Predicho' (Test Set)")


# Asegurarnos de que usamos la lista con la longitud correcta (527 días)
# Asumimos que 'env_eval_test' está en memoria de la celda anterior.
try:
    # Usar la lista completa guardada en el entorno de evaluación
    ppo_test_history_data = env_eval_test.portfolio_value_history

    # Comprobación de longitud
    if len(ppo_test_history_data) != len(spy_test_history.values):
        print(f"Error: Las longitudes no coinciden. PPO: {len(ppo_test_history_data)}, SPY: {len(spy_test_history.values)}")
        # Como fallback, intentar truncar el más largo (aunque esto es un parche)
        min_len = min(len(ppo_test_history_data), len(spy_test_history.values))
        ppo_test_history_data = ppo_test_history_data[:min_len]
        spy_test_history_data = spy_test_history.values[:min_len]
    else:
        spy_test_history_data = spy_test_history.values
        print("Longitudes de PPO y SPY coinciden. Generando gráfico...")

except NameError:
    print("Error: 'env_eval_test' no encontrado. Asegúrese de ejecutar la celda de evaluación (7) primero.")
    # Poner placeholders para evitar que el código se rompa
    ppo_test_history_data = [10000]
    spy_test_history_data = [10000]



# II. Creación del Gráfico (tu código)
plt.figure(figsize=(14, 7))
plt.plot(spy_test_history_data, label='Valor Real (Benchmark: Buy & Hold SPY)', color='green', linestyle='--')
plt.plot(ppo_test_history_data, label='Valor "Predicho" (Agente entrenado con PPO)', color='blue')
plt.title(f'Comparativo Real vs. Predicho en Test Set ({len(data_test)} días)')
plt.xlabel('Días (en el Test Set)')
plt.ylabel('Valor del Portafolio ($)')
plt.grid(True)

# III. Añadir las etiquetas finales

# Obtener las coordenadas del último punto
x_final = len(ppo_test_history_data) - 1
y_final_ppo = ppo_test_history_data[-1]
y_final_spy = spy_test_history_data[-1]

# Formatear el texto de la etiqueta
label_ppo = f'${y_final_ppo:,.2f}' # Formato de moneda, ej: $15,432.10
label_spy = f'${y_final_spy:,.2f}'

# Añadir la etiqueta para la línea PPO (azul)
plt.annotate(
    label_ppo,                          # El texto a mostrar
    xy=(x_final, y_final_ppo),          # El punto (x,y) a señalar (el final de la línea)
    xytext=(x_final + 8, y_final_ppo),  # Dónde poner el texto (8 días a la derecha)
    textcoords='data',                  # Usar coordenadas de datos
    color='blue',
    fontweight='bold',
    va='center',                        # Alineación vertical centrada
    arrowprops=dict(arrowstyle="->", color='blue', connectionstyle="arc3") # Flecha
)

# Añadir la etiqueta para la línea SPY (verde)
plt.annotate(
    label_spy,                          # El texto a mostrar
    xy=(x_final, y_final_spy),          # El punto (x,y) a señalar
    xytext=(x_final + 8, y_final_spy),  # Dónde poner el texto
    textcoords='data',
    color='green',
    fontweight='bold',
    va='center',
    arrowprops=dict(arrowstyle="->", color='green', connectionstyle="arc3") # Flecha
)

# --- 4. Ajustar el gráfico para que quepa el texto ---
# Darle un ~10% de espacio extra a la derecha para las etiquetas
plt.xlim(right=x_final * 1.10)


plt.legend(loc='upper left') # Mover la leyenda para que no choque con las etiquetas
plt.tight_layout()
plt.savefig('ppo_real_vs_predicho_test_set_con_etiquetas.png')
print("Gráfico 'ppo_real_vs_predicho_test_set_con_etiquetas.png' generado.")
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.2.1)
# Requirement already satisfied: yfinance in /usr/local/lib/python3.12/dist-packages (0.2.66)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: stable-baselines3[extra] in /usr/local/lib/python3.12/dist-packages (2.7.0)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (2.8.0+cu126)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (4.12.0.88)
# Requirement already satisfied: pygame in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (2.19.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (0.11.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (11.3.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.9)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (75.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->stable-baselines3[extra]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->stable-baselines3[extra]) (2.19.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.3)
# /tmp/ipython-input-130740049.py:135: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [                       0%                       ]/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning:
#
# datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#
# [**********************67%*******                ]  2 of 3 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning:
#
# datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#
# [*********************100%***********************]  3 of 3 completed
# --- Librerías importadas ---
#
# --- Clase de Entorno 'PortfolioRebalancingEnv' definida ---
#
# --- Función 'split_data_chronological' definida ---
#
# --- Datos descargados para ['SPY', 'DAX', 'GLD'] ---
# Datos totales: 2637 días
# Datos de entrenamiento (Train): 2110 días (del 2015-01-02 al 2023-05-19)
# Datos de prueba (Test): 527 días (del 2023-05-22 al 2025-06-27)
#
# --- Iniciando entrenamiento PPO (Recompensa de Sharpe) ---
# Using cpu device
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning:
#
# datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
# Logging to ./ppo_portfolio_tesis_log_sharpe/PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 730  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 604        |
# |    iterations           | 2          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00694685 |
# |    clip_fraction        | 0.0532     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.65      |
# |    explained_variance   | 0.0104     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.53       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.00584   |
# |    std                  | 0.992      |
# |    value_loss           | 8.93       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 3            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0033692694 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.65        |
# |    explained_variance   | 0.0796       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.12         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00196     |
# |    std                  | 0.996        |
# |    value_loss           | 9.57         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 4           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.004526293 |
# |    clip_fraction        | 0.0406      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.66       |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.19        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00522    |
# |    std                  | 0.995       |
# |    value_loss           | 7.57        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 540        |
# |    iterations           | 5          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00623472 |
# |    clip_fraction        | 0.0285     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.66      |
# |    explained_variance   | 0.313      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.99       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.00291   |
# |    std                  | 0.998      |
# |    value_loss           | 8.55       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 530          |
# |    iterations           | 6            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0035165646 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.66        |
# |    explained_variance   | 0.491        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.26         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00332     |
# |    std                  | 0.992        |
# |    value_loss           | 8.06         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 525          |
# |    iterations           | 7            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0060064513 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.63        |
# |    explained_variance   | 0.616        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.91         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00347     |
# |    std                  | 0.987        |
# |    value_loss           | 8.29         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 518         |
# |    iterations           | 8           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009575168 |
# |    clip_fraction        | 0.0635      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.62       |
# |    explained_variance   | 0.629       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.51        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00429    |
# |    std                  | 0.985       |
# |    value_loss           | 7.29        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 521          |
# |    iterations           | 9            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0049548917 |
# |    clip_fraction        | 0.0443       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.61        |
# |    explained_variance   | 0.617        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.23         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00368     |
# |    std                  | 0.984        |
# |    value_loss           | 6.5          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 522         |
# |    iterations           | 10          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.006045779 |
# |    clip_fraction        | 0.0369      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.62       |
# |    explained_variance   | 0.698       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.45        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0038     |
# |    std                  | 0.988       |
# |    value_loss           | 5.52        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 516         |
# |    iterations           | 11          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.007008208 |
# |    clip_fraction        | 0.064       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.63       |
# |    explained_variance   | 0.66        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.21        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00571    |
# |    std                  | 0.988       |
# |    value_loss           | 7.33        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 515       |
# |    iterations           | 12        |
# |    time_elapsed         | 47        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0081011 |
# |    clip_fraction        | 0.0744    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.62     |
# |    explained_variance   | 0.675     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.73      |
# |    n_updates            | 110       |
# |    policy_gradient_loss | -0.00449  |
# |    std                  | 0.983     |
# |    value_loss           | 6.97      |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 13           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0043114256 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.59        |
# |    explained_variance   | 0.654        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.47         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00496     |
# |    std                  | 0.978        |
# |    value_loss           | 7.1          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 14           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0057438845 |
# |    clip_fraction        | 0.0362       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.57        |
# |    explained_variance   | 0.64         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.88         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00337     |
# |    std                  | 0.971        |
# |    value_loss           | 6.24         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 511          |
# |    iterations           | 15           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0044566076 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.56        |
# |    explained_variance   | 0.641        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.98         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0028      |
# |    std                  | 0.973        |
# |    value_loss           | 6.88         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 513         |
# |    iterations           | 16          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.004518668 |
# |    clip_fraction        | 0.0417      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.55       |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.2         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00403    |
# |    std                  | 0.968       |
# |    value_loss           | 4.91        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 503         |
# |    iterations           | 17          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007961501 |
# |    clip_fraction        | 0.0824      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.53       |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.77        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00604    |
# |    std                  | 0.962       |
# |    value_loss           | 6.83        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 504          |
# |    iterations           | 18           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0070189247 |
# |    clip_fraction        | 0.0521       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.5         |
# |    explained_variance   | 0.679        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.98         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00429     |
# |    std                  | 0.954        |
# |    value_loss           | 6.87         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 506         |
# |    iterations           | 19          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007498293 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.47       |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.73        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00479    |
# |    std                  | 0.949       |
# |    value_loss           | 4.25        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 504         |
# |    iterations           | 20          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.003192116 |
# |    clip_fraction        | 0.0514      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.47       |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.04        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00224    |
# |    std                  | 0.949       |
# |    value_loss           | 5.36        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 506          |
# |    iterations           | 21           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0056780255 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.46        |
# |    explained_variance   | 0.762        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.16         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00442     |
# |    std                  | 0.945        |
# |    value_loss           | 7.26         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 508         |
# |    iterations           | 22          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005524625 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.44       |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.82        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00367    |
# |    std                  | 0.944       |
# |    value_loss           | 6.5         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 506         |
# |    iterations           | 23          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.005138747 |
# |    clip_fraction        | 0.0448      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.43       |
# |    explained_variance   | 0.696       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.5         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00255    |
# |    std                  | 0.937       |
# |    value_loss           | 6.49        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 508         |
# |    iterations           | 24          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006346277 |
# |    clip_fraction        | 0.0603      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.41       |
# |    explained_variance   | 0.603       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.45        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00457    |
# |    std                  | 0.935       |
# |    value_loss           | 6.64        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 25          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.005420774 |
# |    clip_fraction        | 0.0816      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.42       |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.77        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00584    |
# |    std                  | 0.94        |
# |    value_loss           | 4.29        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 507          |
# |    iterations           | 26           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0060259914 |
# |    clip_fraction        | 0.0488       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.43        |
# |    explained_variance   | 0.706        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.51         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00416     |
# |    std                  | 0.943        |
# |    value_loss           | 5.63         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 508         |
# |    iterations           | 27          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.006942601 |
# |    clip_fraction        | 0.0442      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.43       |
# |    explained_variance   | 0.687       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.53        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00359    |
# |    std                  | 0.94        |
# |    value_loss           | 5.8         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 28           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0039822226 |
# |    clip_fraction        | 0.0422       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.43        |
# |    explained_variance   | 0.812        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.68         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00175     |
# |    std                  | 0.943        |
# |    value_loss           | 4.43         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 507         |
# |    iterations           | 29          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.005012622 |
# |    clip_fraction        | 0.0579      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.43       |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.25        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00226    |
# |    std                  | 0.939       |
# |    value_loss           | 5.54        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 508         |
# |    iterations           | 30          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.004350667 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.41       |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.94        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00358    |
# |    std                  | 0.934       |
# |    value_loss           | 6.28        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 508         |
# |    iterations           | 31          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.006112337 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.41       |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.57        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00476    |
# |    std                  | 0.936       |
# |    value_loss           | 5.07        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 32           |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0077871606 |
# |    clip_fraction        | 0.066        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.39        |
# |    explained_variance   | 0.741        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.78         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00382     |
# |    std                  | 0.929        |
# |    value_loss           | 4.48         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 507         |
# |    iterations           | 33          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.009705611 |
# |    clip_fraction        | 0.0774      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.37       |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.26        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00327    |
# |    std                  | 0.926       |
# |    value_loss           | 4.8         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 507          |
# |    iterations           | 34           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0067840437 |
# |    clip_fraction        | 0.0797       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.37        |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.23         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00474     |
# |    std                  | 0.925        |
# |    value_loss           | 4.46         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 507         |
# |    iterations           | 35          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.007946799 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.36       |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.55        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00303    |
# |    std                  | 0.924       |
# |    value_loss           | 4.26        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 507          |
# |    iterations           | 36           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0059088063 |
# |    clip_fraction        | 0.0687       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.33        |
# |    explained_variance   | 0.769        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.77         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0035      |
# |    std                  | 0.911        |
# |    value_loss           | 4.55         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 507         |
# |    iterations           | 37          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.009325661 |
# |    clip_fraction        | 0.0823      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.3        |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.65        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00583    |
# |    std                  | 0.911       |
# |    value_loss           | 5.4         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 38           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0053067748 |
# |    clip_fraction        | 0.0656       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.3         |
# |    explained_variance   | 0.74         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.31         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00352     |
# |    std                  | 0.912        |
# |    value_loss           | 4.8          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 507         |
# |    iterations           | 39          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.006658241 |
# |    clip_fraction        | 0.0583      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.29       |
# |    explained_variance   | 0.71        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.44        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00259    |
# |    std                  | 0.909       |
# |    value_loss           | 5.35        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 507          |
# |    iterations           | 40           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0068696192 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.27        |
# |    explained_variance   | 0.792        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.76         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00412     |
# |    std                  | 0.9          |
# |    value_loss           | 4.46         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 507         |
# |    iterations           | 41          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.004447781 |
# |    clip_fraction        | 0.0512      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.24       |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.63        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0017     |
# |    std                  | 0.895       |
# |    value_loss           | 3.63        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 506         |
# |    iterations           | 42          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008036014 |
# |    clip_fraction        | 0.0855      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.23       |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.43        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00572    |
# |    std                  | 0.896       |
# |    value_loss           | 4.42        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 506          |
# |    iterations           | 43           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0069394247 |
# |    clip_fraction        | 0.0709       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.22        |
# |    explained_variance   | 0.803        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.15         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00384     |
# |    std                  | 0.89         |
# |    value_loss           | 4.64         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 507         |
# |    iterations           | 44          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004674711 |
# |    clip_fraction        | 0.0705      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.2        |
# |    explained_variance   | 0.822       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.29        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00224    |
# |    std                  | 0.89        |
# |    value_loss           | 4.41        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 505         |
# |    iterations           | 45          |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.007833031 |
# |    clip_fraction        | 0.076       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.2        |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.63        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00329    |
# |    std                  | 0.887       |
# |    value_loss           | 3.47        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 506          |
# |    iterations           | 46           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0057071205 |
# |    clip_fraction        | 0.0651       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.18        |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.73         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00439     |
# |    std                  | 0.885        |
# ...
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.09        |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.00662    |
# |    std                  | 0.766       |
# |    value_loss           | 3.89        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 502         |
# |    iterations           | 81          |
# |    time_elapsed         | 329         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.007786046 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.59       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22        |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.00515    |
# |    std                  | 0.764       |
# |    value_loss           | 3.6         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 501          |
# |    iterations           | 82           |
# |    time_elapsed         | 334          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0086851865 |
# |    clip_fraction        | 0.0946       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.57        |
# |    explained_variance   | 0.834        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.31         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00273     |
# |    std                  | 0.759        |
# |    value_loss           | 3.39         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 502          |
# |    iterations           | 83           |
# |    time_elapsed         | 338          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0071923174 |
# |    clip_fraction        | 0.0736       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.54        |
# |    explained_variance   | 0.896        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.64         |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.00481     |
# |    std                  | 0.75         |
# |    value_loss           | 3.44         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 502          |
# |    iterations           | 84           |
# |    time_elapsed         | 342          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0076622013 |
# |    clip_fraction        | 0.087        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.49        |
# |    explained_variance   | 0.889        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.1          |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.00479     |
# |    std                  | 0.744        |
# |    value_loss           | 3.74         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 85          |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.005505029 |
# |    clip_fraction        | 0.0632      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.48       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.18        |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0011     |
# |    std                  | 0.743       |
# |    value_loss           | 4.01        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 502         |
# |    iterations           | 86          |
# |    time_elapsed         | 350         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.005515784 |
# |    clip_fraction        | 0.0537      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.48       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.07        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.00083    |
# |    std                  | 0.745       |
# |    value_loss           | 3.86        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 502         |
# |    iterations           | 87          |
# |    time_elapsed         | 354         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.006589085 |
# |    clip_fraction        | 0.072       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.49       |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.00157    |
# |    std                  | 0.747       |
# |    value_loss           | 3.65        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 501          |
# |    iterations           | 88           |
# |    time_elapsed         | 359          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0076089706 |
# |    clip_fraction        | 0.0842       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.49        |
# |    explained_variance   | 0.854        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.89         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.00185     |
# |    std                  | 0.744        |
# |    value_loss           | 3.93         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 500         |
# |    iterations           | 89          |
# |    time_elapsed         | 364         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.006881738 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.46       |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.24        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.00121    |
# |    std                  | 0.738       |
# |    value_loss           | 4.07        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 500          |
# |    iterations           | 90           |
# |    time_elapsed         | 368          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0074477363 |
# |    clip_fraction        | 0.0769       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.42        |
# |    explained_variance   | 0.806        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.03         |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.00118     |
# |    std                  | 0.727        |
# |    value_loss           | 4.01         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 498          |
# |    iterations           | 91           |
# |    time_elapsed         | 373          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0060421363 |
# |    clip_fraction        | 0.0545       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.37        |
# |    explained_variance   | 0.815        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.06         |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.000696    |
# |    std                  | 0.72         |
# |    value_loss           | 3.83         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 498         |
# |    iterations           | 92          |
# |    time_elapsed         | 377         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.008014837 |
# |    clip_fraction        | 0.0871      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.37       |
# |    explained_variance   | 0.773       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.83        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.00496    |
# |    std                  | 0.727       |
# |    value_loss           | 3.91        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 499        |
# |    iterations           | 93         |
# |    time_elapsed         | 381        |
# |    total_timesteps      | 190464     |
# | train/                  |            |
# |    approx_kl            | 0.00405134 |
# |    clip_fraction        | 0.0626     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.38      |
# |    explained_variance   | 0.804      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.8        |
# |    n_updates            | 920        |
# |    policy_gradient_loss | -0.00119   |
# |    std                  | 0.724      |
# |    value_loss           | 3.68       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 498          |
# |    iterations           | 94           |
# |    time_elapsed         | 386          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0043134177 |
# |    clip_fraction        | 0.0606       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.37        |
# |    explained_variance   | 0.882        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.76         |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.000211    |
# |    std                  | 0.722        |
# |    value_loss           | 3.46         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 498          |
# |    iterations           | 95           |
# |    time_elapsed         | 390          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0054771053 |
# |    clip_fraction        | 0.0722       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.36        |
# |    explained_variance   | 0.803        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.01         |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.00152     |
# |    std                  | 0.719        |
# |    value_loss           | 4.06         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 499          |
# |    iterations           | 96           |
# |    time_elapsed         | 393          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0066899257 |
# |    clip_fraction        | 0.0875       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.34        |
# |    explained_variance   | 0.854        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.57         |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.00305     |
# |    std                  | 0.718        |
# |    value_loss           | 3.64         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 498        |
# |    iterations           | 97         |
# |    time_elapsed         | 398        |
# |    total_timesteps      | 198656     |
# | train/                  |            |
# |    approx_kl            | 0.00787124 |
# |    clip_fraction        | 0.0976     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.33      |
# |    explained_variance   | 0.909      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.86       |
# |    n_updates            | 960        |
# |    policy_gradient_loss | -0.00398   |
# |    std                  | 0.714      |
# |    value_loss           | 3.89       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 498         |
# |    iterations           | 98          |
# |    time_elapsed         | 402         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.009659385 |
# |    clip_fraction        | 0.0776      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.48        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.00217    |
# |    std                  | 0.714       |
# |    value_loss           | 3.52        |
# -----------------------------------------
#
# --- Entrenamiento completado tras 200000 timesteps ---
#
# --- Evaluando el modelo (Sharpe) en el set de 'TEST' (Out-of-Sample) ---
# --- Evaluación 'Out-of-Sample' (Test) completada ---
#
#
# ======================================================================
#   RESULTADO PROMEDIO DE EVALUACIÓN (TEST SET) - ESTRATEGIA PPO
# ======================================================================
# | Portafolio                 |   Retorno Esperado |   Volatilidad |   Sharpe Ratio |   W_SPY (Promedio) |   W_DAX (Promedio) |   W_GLD (Promedio) |   W_Cash (Promedio) |
# |:---------------------------|-------------------:|--------------:|---------------:|-------------------:|-------------------:|-------------------:|--------------------:|
# | PPO (RL) - Promedio (Test) |           0.220144 |      0.155519 |        1.41554 |           0.499896 |                  0 |           0.499481 |         0.000622521 |
#
# --- Calculando Benchmark 'Buy & Hold SPY' ('Valor Real') ---
# Generando gráfico 1: 'Real' vs. 'Predicho' (Test Set)
# Longitudes de PPO y SPY coinciden. Generando gráfico...
# Gráfico 'ppo_real_vs_predicho_test_set_con_etiquetas.png' generado.

# %%
# 10. ¡NUEVO GRÁFICO! - Evolución de Pesos (¡GRÁFICO INTERACTIVO con Plotly!)


# Instalar Kaleido, el motor necesario para guardar gráficos de Plotly como PNG
# !pip install -U kaleido

print("Generando gráfico 2: Evolución de Pesos del Portafolio (Test Set)")

# --- 1. Importar las librerías necesarias ---
import plotly.express as px
import plotly.io as pio
import matplotlib.pyplot as plt # Importar plt para resetear el estilo al final

# Usar un tema claro
pio.templates.default = "plotly_white"

# --- 2. Preparar los datos para Plotly (Formato "Largo") ---
# Renombramos el índice para que sea una columna 'Día'
weights_df_plotly = weights_df.reset_index().rename(columns={'index': 'Día'})

# "Derretimos" (melt) el DataFrame
weights_df_long = weights_df_plotly.melt(
    id_vars='Día',
    var_name='Activo',
    value_name='Proporción'
)

# --- 3. Definir los mismos colores profesionales ---
color_map = {
    'W_SPY': '#007ACC',
    'W_DAX': '#FAA43A',
    'W_GLD': '#60BD68',
    'W_Cash': '#F17CB0'
}

# --- 4. Crear el gráfico de área interactivo ---
fig = px.area(
    weights_df_long,
    x='Día',
    y='Proporción',
    color='Activo', # Esto agrupa Y apila automáticamente
    labels={'Día': 'Días (en el set de prueba)', 'Proporción': 'Proporción del Portafolio', 'Activo': 'Activos'},
    title=f'Evolución de Pesos del Portafolio (Agente PPO) en Set de Prueba ({len(weights_df)} días)',
    color_discrete_map=color_map,
    template=pio.templates.default
)

# --- 5. Mejorar el layout y los tooltips (hover) ---
fig.update_layout(
    yaxis_tickformat='.1%', # Muestra porcentajes con 1 decimal
    xaxis_title='Días (en el set de prueba)',
    yaxis_title='Proporción del Portafolio',
    legend_title='Activos',
    hovermode="x unified" # Muestra todos los valores de ese día
)

# --- 6. Mostrar el gráfico interactivo en el notebook ---
print("Mostrando gráfico interactivo...")
fig.show()

# --- 7. Guardar el gráfico ---

# Guardar como un archivo HTML interactivo
fig.write_html('ppo_weights_evolution_interactivo.html')
print("--- Gráfico 'ppo_weights_evolution_interactivo.html' guardado. ---")

# Guardar como una imagen estática (¡ESTA LÍNEA AHORA FUNCIONARÁ!)

try:
    fig.write_image('ppo_weights_evolution_profesional.png', scale=2)
    print("--- Gráfico 'ppo_weights_evolution_profesional.png' guardado. ---")
except ValueError as e:
    print(f"\n¡Error al guardar la imagen! Asegúrate de que 'kaleido' esté instalado.")
    print(f"Detalle: {e}")


#  Volver al estilo por defecto para matplotlib
plt.style.use('default')
# Out:
# Requirement already satisfied: kaleido in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: choreographer>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from kaleido) (1.2.0)
# Requirement already satisfied: logistro>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from kaleido) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in /usr/local/lib/python3.12/dist-packages (from kaleido) (3.11.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kaleido) (25.0)
# Requirement already satisfied: pytest-timeout>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from kaleido) (2.4.0)
# Requirement already satisfied: simplejson>=3.19.3 in /usr/local/lib/python3.12/dist-packages (from choreographer>=1.1.1->kaleido) (3.20.2)
# Requirement already satisfied: pytest>=7.0.0 in /usr/local/lib/python3.12/dist-packages (from pytest-timeout>=2.4.0->kaleido) (8.4.2)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (2.19.2)
# Generando gráfico 2: Evolución de Pesos del Portafolio (Test Set)
# Mostrando gráfico interactivo...
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning:
#
# datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="70e02186-927b-44a8-8681-51c94fe4a0e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("70e02186-927b-44a8-8681-51c94fe4a0e2")) {                    Plotly.newPlot(                        "70e02186-927b-44a8-8681-51c94fe4a0e2",                        [{"fillpattern":{"shape":""},"hovertemplate":"Activos=SPY\u003cbr\u003eDías (en el set de prueba)=%{x}\u003cbr\u003eProporción del Portafolio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SPY","line":{"color":"#FFA15A"},"marker":{"symbol":"circle"},"mode":"lines","name":"SPY","orientation":"v","showlegend":true,"stackgroup":"1","x":{"dtype":"i2","bdata":"\\u002fAD9AP4A\u002fwAAAQEBAgEDAQQBBQEGAQcBCAEJAQoBCwEMAQ0BDgEPARABEQESARMBFAEVARYBFwEYARkBGgEbARwBHQEeAR8BIAEhASIBIwEkASUBJgEnASgBKQEqASsBLAEtAS4BLwEwATEBMgEzATQBNQE2ATcBOAE5AToBOwE8AT0BPgE\...\u002fgH\u002fAQACAQICAgMCBAIFAgYCBwIIAgkCCgILAgwCDQI="},"xaxis":"x","y":{"dtype":"f4","bdata":"aWzyPj6j8T4AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002fAAAAPwAAAD8AAAA\u002 ...
# --- Gráfico 'ppo_weights_evolution_interactivo.html' guardado. ---
# /usr/local/lib/python3.12/dist-packages/plotly/io/_kaleido.py:528: DeprecationWarning:
#
#
# Support for the 'engine' argument is deprecated and will be removed after September 2025.
# Kaleido will be the only supported engine at that time.
# ---------------------------------------------------------------------------
# ChromeNotFoundError                       Traceback (most recent call last)
# ChromeNotFoundError:
#
# The above exception was the direct cause of the following exception:
#
# ChromeNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/plotly/io/_kaleido.py in to_image(fig, format, width, height, scale, validate, engine)
#     397
# --> 398             img_bytes = kaleido.calc_fig_sync(
#     399                 fig_dict,
#
# /usr/local/lib/python3.12/dist-packages/kaleido/__init__.py in calc_fig_sync(*args, **kwargs)
#     170     else:
# --> 171         return _sync_server.oneshot_async_run(calc_fig, args=args, kwargs=kwargs)
#     172
#
# /usr/local/lib/python3.12/dist-packages/kaleido/_sync_server.py in oneshot_async_run(func, args, kwargs)
#     130     if isinstance(res, BaseException):
# --> 131         raise res
#     132     else:
#
# /usr/local/lib/python3.12/dist-packages/kaleido/_sync_server.py in run(func, q, *args, **kwargs)
#     121         try:
# --> 122             q.put(asyncio.run(func(*args, **kwargs)))
#     123         except BaseException as e:  # noqa: BLE001
#
# /usr/lib/python3.12/asyncio/runners.py in run(main, debug, loop_factory)
#     194     with Runner(debug=debug, loop_factory=loop_factory) as runner:
# --> 195         return runner.run(main)
#     196
#
# /usr/lib/python3.12/asyncio/runners.py in run(self, coro, context)
#     117         try:
# --> 118             return self._loop.run_until_complete(task)
#     119         except exceptions.CancelledError:
#
# /usr/lib/python3.12/asyncio/base_events.py in run_until_complete(self, future)
#     690
# --> 691         return future.result()
#     692
#
# /usr/local/lib/python3.12/dist-packages/kaleido/__init__.py in calc_fig(fig, path, opts, topojson, kopts)
#     100     kopts["n"] = 1  # should we force this?
# --> 101     async with Kaleido(**kopts) as k:
#     102         return await k.calc_fig(
#
# /usr/local/lib/python3.12/dist-packages/kaleido/kaleido.py in __init__(self, page_generator, n, timeout, width, height, stepper, plotlyjs, mathjax, *args, **kwargs)
#     163         except ChromeNotFoundError:
# --> 164             raise ChromeNotFoundError(
#     165                 "Kaleido v1 and later requires Chrome to be installed. "
#
# ChromeNotFoundError: Kaleido v1 and later requires Chrome to be installed. To install Chrome, use the CLI command `kaleido_get_chrome`, or from Python, use either `kaleido.get_chrome()` or `kaleido.get_chrome_sync()`.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-745065565.py in <cell line: 0>()
#      70 # 'scale=2' aumenta la resolución para que se vea bien en Word/PDF
#      71 try:
# ---> 72     fig.write_image('ppo_weights_evolution_profesional.png', scale=2)
#      73     print("--- Gráfico 'ppo_weights_evolution_profesional.png' guardado. ---")
#      74 except ValueError as e:
#
# /usr/local/lib/python3.12/dist-packages/plotly/basedatatypes.py in write_image(self, *args, **kwargs)
#    3893                     ENGINE_PARAM_DEPRECATION_MSG, DeprecationWarning, stacklevel=2
#    3894                 )
# -> 3895         return pio.write_image(self, *args, **kwargs)
#    3896
#    3897     # Static helpers
#
# /usr/local/lib/python3.12/dist-packages/plotly/io/_kaleido.py in write_image(fig, file, format, scale, width, height, validate, engine)
#     526     # Request image
#     527     # Do this first so we don't create a file if image conversion fails
# --> 528     img_data = to_image(
#     529         fig,
#     530         format=format,
#
# /usr/local/lib/python3.12/dist-packages/plotly/io/_kaleido.py in to_image(fig, format, width, height, scale, validate, engine)
#     408             )
#     409         except ChromeNotFoundError:
# --> 410             raise RuntimeError(PLOTLY_GET_CHROME_ERROR_MSG)
#     411
#     412     else:
#
# RuntimeError:
#
# Kaleido requires Google Chrome to be installed.
#
# Either download and install Chrome yourself following Google's instructions for your operating system,
# or install it from your terminal by running:
#
#     $ plotly_get_chrome
